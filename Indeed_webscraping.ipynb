# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Instal Firefox, Selenium, Gecko Driver, Beautiful Soup

# %%
#Install firefox
# !apt-get update
# !apt install firefox

#Install selenium
# !pip install selenium

#Updating and installing firefox libraries
# !apt-get update && apt-get install -y wget bzip2 libxtst6 libgtk-3-0 libx11-xcb-dev libdbus-glib-1-2 libxt6 libpci-dev && rm -rf /var/lib/apt/lists/*

#Installing Geck Driver
# !wget https://github.com/mozilla/geckodriver/releases/download/v0.24.0/geckodriver-v0.24.0-linux64.tar.gz
# !tar -xvzf geckodriver*
# !chmod +x geckodriver
# !export PATH=$PATH:/path-to-extracted-file/.

#Instal beautifulsoup
# !pip install beautifulsoup4
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: selenium in c:\users\asus\anaconda3\lib\site-packages (4.15.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\asus\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\asus\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\asus\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\asus\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'geckodriver*'
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)

# %% [markdown]
# ### Import Dependencies

# %%
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions

import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

import random
import time

# %% [markdown]
# ### Define Position and Location

# %%
## Enter a job position
position = "data+scientist"
## Enter a location (City, State or Zip or remote)
locations = "NewYork"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
print(url)
# Out:
# https://www.indeed.com/jobs?q=data+scientist&l=NewYork

# %% [markdown]
# ### Set Path to Webdriver

# %%
driver_path = '/content/geckodriver'
firefox_driver_path = '/content/geckodriver'
user_agent = 'Mozilla'
firefox_options = FirefoxOptions()
firefox_options.add_argument('--headless')
driver = webdriver.Firefox(options=firefox_options)

# %% [markdown]
# ### Scrape Job Postings

# %%
## Number of postings to scrape
postings = 200
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
jn=0
for i in range(100, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')
    #print(jobs)

    for job in jobs:
        #print(job)
        result_html = job.get_attribute('innerHTML')
        #print(result_html)
        soup = BeautifulSoup(result_html, 'html.parser')
        #print(soup , '\n')

        jn += 1

        liens = job.find_elements(By.TAG_NAME, "a")
        #print(liens)
        links = liens[0].get_attribute("href")
        #print(links)

        title = soup.select('.jobTitle')[0].get_text().strip()
        print(title)

        #company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
        #print(company)
        try:
            company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
            #print(company)
        except:
            company = 'Nan'
        print(company)
        #location = soup.select('.companyLocation')[0].get_text().strip() #origional
        #location = soup.select('.company_location')[0].get_text().strip()
        location = soup.find_all(attrs={'data-testid': 'text-location'})[0].get_text().strip()
        print(location)
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''

        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Research Computing and Data Science Facilitator
# University at Buffalo
# Hybrid remote in Buffalo, NY 14260
# Job number    1 added - Research Computing and Data Science Facilitator
# Artificial Intelligence Engineer (AI Engineer)
# Integrass
# Hybrid remote in New York, NY 10001
# Job number    2 added - Artificial Intelligence Engineer (AI Engineer)
# Senior AI Specialist, Solution Consulting
# ServiceNow
# Remote in New York, NY
# Job number    3 added - Senior AI Specialist, Solution Consulting
# Lead Decision Scientist - EDA Product
# CVS Health
# New York, NY
# Job number    4 added - Lead Decision Scientist - EDA Product
# Senior Data Analyst, Amazon
# Harry's
# New York, NY 10004 (Financial District area)
# Job number    5 added - Senior Data Analyst, Amazon
# Director, Data Science Engineering
# Dassault Systèmes
# New York, NY
# Job number    6 added - Director, Data Science Engineering
# Machine Learning Engineering Lead
# MMC Corporate
# New York, NY 10036 (Midtown area)
# Job number    7 added - Machine Learning Engineering Lead
# Software Engineer - Machine Learning
# CUBRC INC
# Buffalo, NY 14225
# Job number    8 added - Software Engineer - Machine Learning
# Data Analytics Lead
# Carrier
# East Syracuse, NY 13057
# Job number    9 added - Data Analytics Lead
# Senior Applied Scientist, Ad Measurements Science
# Amazon.com Services LLC
# New York, NY
# Job number   10 added - Senior Applied Scientist, Ad Measurements Science
# Data Science Engineer
# CUBRC INC
# Buffalo, NY 14225
# Job number   11 added - Data Science Engineer
# Data Scientist-Healthcare Analytics
# Staffing Solutions Organization LLC (SSO)
# Remote in Albany, NY 12210
# Job number   12 added - Data Scientist-Healthcare Analytics
# Senior Decision Scientist
# JPMorgan Chase & Co
# New York, NY 10172 (Gramercy area)
# Job number   13 added - Senior Decision Scientist
# AI Scientist, Deep Learning
# Absci
# Remote in New York, NY
# Job number   14 added - AI Scientist, Deep Learning
# Statistician (Clinical Business Analyst Level I), Quality and Safety
# NYC Health + Hospitals
# New York, NY
# Job number   15 added - Statistician (Clinical Business Analyst Level I), Quality and Safety
# Principal Data Scientist, Experimentation
# Rokt
# Hybrid remote in New York, NY 10014
# Job number   16 added - Principal Data Scientist, Experimentation
# Machine Learning Engineer, Control Lab
# NANOTRONICS IMAGING INC
# Brooklyn, NY 11205 (Fort Green area)
# Job number   17 added - Machine Learning Engineer, Control Lab
# Senior AI Research Engineer, Recommendation
# Duolingo
# New York, NY
# Job number   18 added - Senior AI Research Engineer, Recommendation
# 3224 - Data Engineer
# Infoorigin inc
# Armonk, NY 10504
# Job number   19 added - 3224 - Data Engineer
# Postdoctoral researcher – Data Science For Fisheries Management
# Cary Institute of Ecosystem Studies
# Millbrook, NY
# Job number   20 added - Postdoctoral researcher – Data Science For Fisheries Management
# AI/ML - NLP Engineer - Vice President
# iCapital
# New York, NY
# Job number   21 added - AI/ML - NLP Engineer - Vice President
# Data Analytics and ML Developer
# Katalyst Healthcares & Life Sciences
# Syracuse, NY 13201 (Downtown area)
# Job number   22 added - Data Analytics and ML Developer
# Senior Data Analyst
# Coordinated Behavioral Care, Inc.
# Hybrid remote in New York, NY 10006
# Job number   23 added - Senior Data Analyst
# Sr. Applied Scientist - Delivery Pricing
# Uber
# New York, NY
# Job number   24 added - Sr. Applied Scientist - Delivery Pricing
# Senior Staff Data Scientist
# Udemy
# Remote in New York, NY
# Job number   25 added - Senior Staff Data Scientist
# Research Engineer, Language - Generative AI
# Meta
# New York, NY
# Job number   26 added - Research Engineer, Language - Generative AI
# Data Science Analyst II (Dr Elahi's Lab) - Neurology
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number   27 added - Data Science Analyst II (Dr Elahi's Lab) - Neurology
# Educator, Data Scientist
# BrainStation
# New York, NY
# Job number   28 added - Educator, Data Scientist
# Applied Scientist
# TikTok
# New York, NY
# Job number   29 added - Applied Scientist
# Principal Data Scientist
# FalconSmartIT
# Boston, NY 14025
# Job number   30 added - Principal Data Scientist
# Applied Scientist
# TikTok
# New York, NY
# Job number   31 added - Applied Scientist
# Principal Data Scientist
# FalconSmartIT
# Boston, NY 14025
# Job number   32 added - Principal Data Scientist
# Data Engineer, Product Analytics
# Meta
# New York, NY
# Job number   33 added - Data Engineer, Product Analytics
# Data Scientist
# DELUXE CORPORATION
# New York, NY 10011 (Flatiron area)
# Job number   34 added - Data Scientist
# Machine Learning Research Scientist, Hit Discovery
# Schrödinger
# New York, NY
# Job number   35 added - Machine Learning Research Scientist, Hit Discovery
# Senior Staff Associate I (Senior Data Analyst)
# Columbia University
# New York, NY 10032 (Washington Heights area)
# Job number   36 added - Senior Staff Associate I (Senior Data Analyst)
# AIML - Sr. Machine Learning Engineer - Data and ML Infrastructure for Machine Translation
# Apple
# New York, NY
# Job number   37 added - AIML - Sr. Machine Learning Engineer - Data and ML Infrastructure for Machine Translation
# CVP, Director of Data Science, Geospatial Analytics
# New York Life Insurance Co
# New York, NY
# Job number   38 added - CVP, Director of Data Science, Geospatial Analytics
# Data Engineer/Sr Data Engineer
# DNV
# Remote in New York, NY
# Job number   39 added - Data Engineer/Sr Data Engineer
# Senior Researcher - Artificial Intelligence, Machine Learning, and Reinforcement Learning (Algorithmic/Representation) – Microsoft Research
# Microsoft
# New York, NY
# Job number   40 added - Senior Researcher - Artificial Intelligence, Machine Learning, and Reinforcement Learning (Algorithmic/Representation) – Microsoft Research
# Senior Data Analyst
# NYC Careers
# Manhattan, NY 10004 (Financial District area)
# Job number   41 added - Senior Data Analyst
# Data Science Team Lead
# Inclusively
# Hybrid remote in New York, NY 10017
# Job number   42 added - Data Science Team Lead
# Sports Statistician - Worldwide
# Genius Sports
# New York, NY
# Job number   43 added - Sports Statistician - Worldwide
# Machine Learning Engineer
# fluxtek Solutions
# East Syracuse, NY 13057
# Job number   44 added - Machine Learning Engineer
# Data Engineer, Product Analytics
# Meta
# New York, NY
# Job number   45 added - Data Engineer, Product Analytics
# Senior Data Scientist
# Yext
# New York, NY 10010 (NoMad area)
# Job number   46 added - Senior Data Scientist
# Artificial Intelligence Research Scientist, Reinforcement Learning and Multi-Agent Learning/Simulation- Vice President
# JPMorgan Chase & Co
# New York, NY 10179 (Midtown area)
# Job number   47 added - Artificial Intelligence Research Scientist, Reinforcement Learning and Multi-Agent Learning/Simulation- Vice President
# Data Science Analyst I (Dr. Schlessinger's Lab) - Pharmacological Sciences
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number   48 added - Data Science Analyst I (Dr. Schlessinger's Lab) - Pharmacological Sciences
# Senior Data Scientist AI & Machine Learning - Manufacturing Systems
# PepsiCo
# Valhalla, NY 10595
# Job number   49 added - Senior Data Scientist AI & Machine Learning - Manufacturing Systems
# Senior Data Analyst/Manager
# Maimonides Medical Center
# Brooklyn, NY
# Job number   50 added - Senior Data Analyst/Manager
# Director of Data and AI
# Otis Wealth
# New York, NY
# Job number   51 added - Director of Data and AI
# Research Engineer - FAIR AI-Guided Design
# Meta
# New York, NY
# Job number   52 added - Research Engineer - FAIR AI-Guided Design
# Artificial Intelligence Project Coordinator
# Division of Information Technology - NYC...
# Hybrid remote in Long Island City, NY 11101
# Job number   53 added - Artificial Intelligence Project Coordinator
# Health Statistician
# Madison County, New York
# Wampsville, NY 13032
# Job number   54 added - Health Statistician
# 2024 BNY Mellon Analyst Program - Engineering (Data Science)
# BNY Mellon
# New York, NY
# Job number   55 added - 2024 BNY Mellon Analyst Program - Engineering (Data Science)
# Senior Product Manager, Machine Learning
# Jobs for Humanity
# Hybrid remote in New York, NY
# Job number   56 added - Senior Product Manager, Machine Learning
# Asset Management –Product Owner/Strategy (Data Science) – Executive Director
# JPMorgan Chase & Co
# New York, NY 10172 (Gramercy area)
# Job number   57 added - Asset Management –Product Owner/Strategy (Data Science) – Executive Director
# Generative AI Strategist, Generative AI Innovation Center
# Amazon Development Center U.S., Inc.
# New York, NY
# Job number   58 added - Generative AI Strategist, Generative AI Innovation Center
# Senior Computational Scientist - Scientific Computing & Data
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number   59 added - Senior Computational Scientist - Scientific Computing & Data
# Data Analytics & Insights Manager (Hybrid)
# Equitable
# Syracuse, NY
# Job number   60 added - Data Analytics & Insights Manager (Hybrid)
# Senior Data Analyst
# Prutech Solutions
# New York, NY 10007 (Financial District area)
# Job number   61 added - Senior Data Analyst
# Machine Learning Engineer
# Altice USA
# Long Island City, NY 11101
# Job number   62 added - Machine Learning Engineer
# Data Scientist
# FARM
# Lancaster, NY 14043
# Job number   63 added - Data Scientist
# Lead Data Scientist
# Fusemachines
# New York, NY
# Job number   64 added - Lead Data Scientist
# Machine Learning Engineer (Entry Level)
# SRC, Inc.
# Syracuse, NY
# Job number   65 added - Machine Learning Engineer (Entry Level)
# Member of Technical Staff, Machine Learning
# Runway
# Remote in New York, NY 10014
# Job number   66 added - Member of Technical Staff, Machine Learning
# Senior Data Analyst, Emerging Business
# Peloton
# New York, NY 10011 (Chelsea area)
# Job number   67 added - Senior Data Analyst, Emerging Business
# Senior Data Analyst
# NYC Careers
# Manhattan, NY
# Job number   68 added - Senior Data Analyst
# Generative AI Strategist, Generative AI Innovation Center
# Amazon Web Services, Inc.
# New York, NY
# Job number   69 added - Generative AI Strategist, Generative AI Innovation Center
# Data Analyst - Policy, Research & Analysis
# NYC Careers
# Manhattan, NY 10007 (Financial District area)
# Job number   70 added - Data Analyst - Policy, Research & Analysis
# Senior Vice President, Data Excellence and Privacy
# Association of National Advertisers
# New York, NY 10017 (Midtown area)
# Job number   71 added - Senior Vice President, Data Excellence and Privacy
# AI/ML Python Developer
# Infoorigin inc
# New York, NY 10001 (Garment District area)
# Job number   72 added - AI/ML Python Developer
# Aumni - Director of Product Management, Data and AI Solutions
# JPMorgan Chase & Co
# New York, NY 10179 (Midtown area)
# Job number   73 added - Aumni - Director of Product Management, Data and AI Solutions
# Machine Learning Engineer
# Neotech Solutions
# Syracuse, NY
# Job number   74 added - Machine Learning Engineer
# Senior Data Scientist
# Brigit
# New York, NY
# Job number   75 added - Senior Data Scientist
# Senior Data Scientist
# Brigit
# New York, NY
# Job number   76 added - Senior Data Scientist
# Software Engineering Manager, Machine Learning
# Meta
# New York, NY
# Job number   77 added - Software Engineering Manager, Machine Learning
# Sr. Data Scientist
# Fanatics
# New York, NY
# Job number   78 added - Sr. Data Scientist
# Training & Placement on Gen AI
# Precision Technologies Corp
# New York, NY
# Job number   79 added - Training & Placement on Gen AI
# Senior Director of Machine Learning
# Jobs for Humanity
# Hybrid remote in New York, NY
# Job number   80 added - Senior Director of Machine Learning
# Senior Quality Data Analyst
# NYC Health + Hospitals
# New York, NY
# Job number   81 added - Senior Quality Data Analyst
# Senior Ops Generative AI Software Engineer
# Citi
# New York, NY
# Job number   82 added - Senior Ops Generative AI Software Engineer
# Director (Acquistion Analytics), Data Science & Modeling
# Merrick Bank
# Remote in Woodbury, NY 11797
# Job number   83 added - Director (Acquistion Analytics), Data Science & Modeling
# Lead Data Scientist, Corporate Vice President
# New York Life Insurance Co
# New York, NY
# Job number   84 added - Lead Data Scientist, Corporate Vice President
# Battery Machine Learning Engineer
# Schrödinger
# New York, NY
# Job number   85 added - Battery Machine Learning Engineer
# Battery Machine Learning Force Fields Scientist
# Schrödinger
# New York, NY
# Job number   86 added - Battery Machine Learning Force Fields Scientist
# ML/AI Developer
# Business Integra Inc.
# New York, NY
# Job number   87 added - ML/AI Developer
# Data Engineering Manager, Analytics
# Meta
# New York, NY
# Job number   88 added - Data Engineering Manager, Analytics
# Senior Cloud Engineer- AI/ML Focus
# Weill Cornell Medicine
# New York, NY 10022 (Midtown area)
# Job number   89 added - Senior Cloud Engineer- AI/ML Focus
# Senior Software Development Engineer, Security Analytics and AI Research
# Amazon Development Center U.S., Inc.
# New York, NY
# Job number   90 added - Senior Software Development Engineer, Security Analytics and AI Research
# Quantitative Systematic Trader – Graduate
# Susquehanna International Group
# New York, NY
# Job number   91 added - Quantitative Systematic Trader – Graduate
# Senior Lead Software Engineer - Data Engineering
# JPMorgan Chase & Co
# New York, NY 10001 (Chelsea area)
# Job number   92 added - Senior Lead Software Engineer - Data Engineering
# Artificial Intelligence Research Scientist - Senior Associate
# JPMorgan Chase & Co
# New York, NY 10179 (Midtown area)
# Job number   93 added - Artificial Intelligence Research Scientist - Senior Associate
# Senior Consultant, Data Strategy
# Publicis Sapient
# New York, NY
# Job number   94 added - Senior Consultant, Data Strategy
# Senior Data Scientist
# Publicis Groupe
# New York, NY 10014 (SoHo area)
# Job number   95 added - Senior Data Scientist
# Lead Data Analyst/Senior Data Analyst, Tiktok Ads - USDS
# TikTok
# Hybrid remote in New York, NY
# Job number   96 added - Lead Data Analyst/Senior Data Analyst, Tiktok Ads - USDS
# Director, Data Science
# Major League Baseball
# New York, NY 10017 (Midtown area)
# Job number   97 added - Director, Data Science
# Statistical Reporting Analyst I or II (Hybrid)
# Utica Mutual Insurance Company
# New Hartford, NY
# Job number   98 added - Statistical Reporting Analyst I or II (Hybrid)
# Open Rank Tenure-Track Positions in Artificial Intelligence (AI)
# New York University
# New York, NY 10012 (Greenwich Village area)
# Job number   99 added - Open Rank Tenure-Track Positions in Artificial Intelligence (AI)
# Sr. Data Analyst
# accelerate360
# New York, NY 10004 (Financial District area)
# Job number  100 added - Sr. Data Analyst
# Vice President - AIML and Data Science for Enterprise Model Validation and Validation Execution
# Morgan Stanley
# New York, NY 10036 (Midtown area)
# Job number  101 added - Vice President - AIML and Data Science for Enterprise Model Validation and Validation Execution
# Senior Product Manager - Artificial Intelligence & Human Health Research
# Mount Sinai
# Manhattan, NY 10065 (Upper East Side area)
# Job number  102 added - Senior Product Manager - Artificial Intelligence & Human Health Research
# Senior NLP Engineer
# Dataworks
# Hybrid remote in New York, NY 10001
# Job number  103 added - Senior NLP Engineer
# ML Engineer (NYC or Remote)
# Trunk Tools, Inc.
# Remote in New York State
# Job number  104 added - ML Engineer (NYC or Remote)
# Model Validation and Governance
# New York Life Insurance Co
# New York State
# Job number  105 added - Model Validation and Governance
# Model Validation and Governance
# New York Life Insurance Co
# New York State
# Job number  106 added - Model Validation and Governance
# Lead Data Engineer
# EXL Services
# New York, NY
# Job number  107 added - Lead Data Engineer
# Senior Director, Data Science
# Pfizer
# New York, NY
# Job number  108 added - Senior Director, Data Science
# Tech Lead Manager, Machine Learning Scientist
# Captions
# New York, NY
# Job number  109 added - Tech Lead Manager, Machine Learning Scientist
# Statistical Programmer
# IAVI
# (Financial District area)Remote
# Job number  110 added - Statistical Programmer
# SVP Generative AI Common Platform Engineer
# Citi
# New York, NY
# Job number  111 added - SVP Generative AI Common Platform Engineer
# Program Manager II, Research Data Systems - Tisch Cancer Institute
# Mount Sinai Health System
# New York, NY 10029 (Yorkville area)
# Job number  112 added - Program Manager II, Research Data Systems - Tisch Cancer Institute
# Lead Machine Learning Engineer, Corporate Vice President
# New York Life Insurance Co
# New York, NY
# Job number  113 added - Lead Machine Learning Engineer, Corporate Vice President
# Staff Machine Learning Platform Engineer - Remote
# Clari
# Remote in New York, NY
# Job number  114 added - Staff Machine Learning Platform Engineer - Remote
# SVP Gen AI - Innovation Lab, Hybrid
# Citi
# New York, NY
# Job number  115 added - SVP Gen AI - Innovation Lab, Hybrid
# Research Associate Positions in Machine Learning
# Center for Advanced Imaging Innovation and...
# New York, NY 10016 (Tudor City area)
# Job number  116 added - Research Associate Positions in Machine Learning
# Data Scientist ML/AI/LM/LMM (remote)
# Pearson
# Remote in Albany, NY 12260
# Job number  117 added - Data Scientist ML/AI/LM/LMM (remote)
# Expert Senior Manager, Machine Learning Engineer
# Bain & Company
# New York, NY 10036 (Midtown area)
# Job number  118 added - Expert Senior Manager, Machine Learning Engineer
# Senior Risk Adjustment Data Analyst - Remote
# EmblemHealth
# Remote in New York, NY
# Job number  119 added - Senior Risk Adjustment Data Analyst - Remote
# Senior Decision Scientist - Enterprise Digital Analytics
# CVS Health
# Hybrid remote in New York, NY
# Job number  120 added - Senior Decision Scientist - Enterprise Digital Analytics
# Data Scientist
# NYC Careers
# Manhattan, NY 10004 (Financial District area)
# Job number  121 added - Data Scientist
# Senior Data Engineer
# Codeignitors inc
# Irving, NY 14081
# Job number  122 added - Senior Data Engineer
# Principal Machine Learning Engineer
# Figure
# Remote in New York, NY 10027
# Job number  123 added - Principal Machine Learning Engineer
# Senior Data Quality Engineer, Corporate Vice President
# New York Life Insurance Co
# New York, NY
# Job number  124 added - Senior Data Quality Engineer, Corporate Vice President
# Senior Software Engineer - AI Platform (NY)
# AlphaSense
# New York, NY 10003 (Flatiron area)
# Job number  125 added - Senior Software Engineer - AI Platform (NY)
# Generative AI CoE Lead, Generative AI Innovation Center
# Amazon Web Services, Inc.
# New York, NY
# Job number  126 added - Generative AI CoE Lead, Generative AI Innovation Center
# Data Analyst I - Windreich Department of Artificial Intelligence & Human Health
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number  127 added - Data Analyst I - Windreich Department of Artificial Intelligence & Human Health
# Director of Data Science and Innovation
# NYC Careers
# Brooklyn, NY
# Job number  128 added - Director of Data Science and Innovation
# CIR Statistician, Bureau of Immunization Statistician
# NYC Careers
# Queens, NY 11101
# Job number  129 added - CIR Statistician, Bureau of Immunization Statistician
# GenAI Lead Data Scientist, Corporate Vice President
# New York Life Insurance Co
# New York, NY
# Job number  130 added - GenAI Lead Data Scientist, Corporate Vice President
# Sr. Operations Data Analyst (SAS Required) - Remote
# EmblemHealth
# Remote in New York, NY
# Job number  131 added - Sr. Operations Data Analyst (SAS Required) - Remote
# Senior Healthcare Data Analyst - Data Quality
# Staffing Solutions Organization LLC (SSO)
# Hybrid remote in Albany, NY 12210
# Job number  132 added - Senior Healthcare Data Analyst - Data Quality
# Senior Demand Planning Data Analyst
# Kiss Products
# Port Washington, NY
# Job number  133 added - Senior Demand Planning Data Analyst
# Senior Data Analyst
# Altice USA
# Long Island City, NY 11101
# Job number  134 added - Senior Data Analyst
# Natural Language Processing (NLP) Researcher
# Kitware
# Hybrid remote in Clifton Park, NY
# Job number  135 added - Natural Language Processing (NLP) Researcher
# Senior Business Intelligence Data Analyst
# NYC Careers
# Queens, NY
# Job number  136 added - Senior Business Intelligence Data Analyst
# Data Engineer II- Windreich Department of Artificial Intelligence & Human Health
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number  137 added - Data Engineer II- Windreich Department of Artificial Intelligence & Human Health
# Senior Business Data Analyst
# Nyne Infotech
# Hybrid remote in New York, NY 10281
# Job number  138 added - Senior Business Data Analyst
# Software Engineer, Machine Learning
# Meta
# New York, NY
# Job number  139 added - Software Engineer, Machine Learning
# Machine Learning Engineer
# Kitware
# Rome, NY
# Job number  140 added - Machine Learning Engineer
# Project Manager, Product Data Operations
# Facebook App
# New York, NY
# Job number  141 added - Project Manager, Product Data Operations
# Software Engineer, Machine Learning
# Meta
# New York, NY
# Job number  142 added - Software Engineer, Machine Learning
# Machine Learning Engineer
# Publicis Groupe
# New York, NY 10014 (SoHo area)
# Job number  143 added - Machine Learning Engineer
# Principal Applied Scientist - Search
# Adswizz
# Remote in New York, NY
# Job number  144 added - Principal Applied Scientist - Search
# Assistant Statistical Analyst
# Pearson
# Albany, NY 12260 (West Hill area)
# Job number  145 added - Assistant Statistical Analyst
# Data Coordinator I - Medicine Clinical Trials Office (REDCap)
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number  146 added - Data Coordinator I - Medicine Clinical Trials Office (REDCap)
# Director Operational Data Science and Systems
# Metropolitan Transportation Authority
# New York, NY 11221 (Bedford Stuyvesant area)
# Job number  147 added - Director Operational Data Science and Systems
# Sr. SDE - ML + Big Data, Measurement, Ad Tech, and Data Science (MADS)
# Amazon.com Services LLC - A57
# New York, NY
# Job number  148 added - Sr. SDE - ML + Big Data, Measurement, Ad Tech, and Data Science (MADS)
# Post Doc Researcher - Artificial Intelligence, Machine Learning, and Reinforcement Learning (Theoretical) – Microsoft Research
# Microsoft
# New York, NY
# Job number  149 added - Post Doc Researcher - Artificial Intelligence, Machine Learning, and Reinforcement Learning (Theoretical) – Microsoft Research
# Materials Data Associate- Receiving - Mount Sinai Hospital - Full Time - Days
# Mount Sinai
# New York, NY 10029 (Yorkville area)
# Job number  150 added - Materials Data Associate- Receiving - Mount Sinai Hospital - Full Time - Days

# %%
dataframe
# Out:
#                                                  Title  \
# 0      Research Computing and Data Science Facilitator
# 1       Artificial Intelligence Engineer (AI Engineer)
# 2            Senior AI Specialist, Solution Consulting
# 3                Lead Decision Scientist - EDA Product
# 4                          Senior Data Analyst, Amazon
# ..                                                 ...
# 145  Data Coordinator I - Medicine Clinical Trials ...
# 146      Director Operational Data Science and Systems
# 147  Sr. SDE - ML + Big Data, Measurement, Ad Tech,...
# 148  Post Doc Researcher - Artificial Intelligence,...
# 149  Materials Data Associate- Receiving - Mount Si...
#
#                                    Company  \
# 0                    University at Buffalo
# 1                                Integrass
# 2                               ServiceNow
# 3                               CVS Health
# 4                                  Harry's
# ..                                     ...
# 145                            Mount Sinai
# 146  Metropolitan Transportation Authority
# 147          Amazon.com Services LLC - A57
# 148                              Microsoft
# 149                            Mount Sinai
#
#                                          Location Rating  \
# 0              Hybrid remote in Buffalo, NY 14260    NaN
# 1             Hybrid remote in New York, NY 10001    NaN
# 2                          Remote in New York, NY    NaN
# 3                                    New York, NY    NaN
# 4    New York, NY 10004 (Financial District area)    NaN
# ..                                            ...    ...
# 145           New York, NY 10029 (Yorkville area)    NaN
# 146  New York, NY 11221 (Bedford Stuyvesant area)    NaN
# 147                                  New York, NY    NaN
# 148                                  New York, NY    NaN
# 149           New York, NY 10029 (Yorkville area)    NaN
#
#                                                   Date  \
# 0                            PostedPosted 30+ days ago
# 1                            PostedPosted 30+ days ago
# 2                            PostedPosted 30+ days ago
# 3                             PostedPosted 22 days ago
# 4    PostedPosted 30+ days ago •Many applications i...
# ..                                                 ...
# 145                          PostedPosted 30+ days ago
# 146                          PostedPosted 30+ days ago
# 147                            PostedPosted 7 days ago
# 148                          PostedPosted 30+ days ago
# 149  PostedPosted 30+ days ago •Many applications i...
#
#                                Salary  \
# 0                                 NaN
# 1                                 NaN
# 2          $165,825 - $273,675 a year
# 3          $132,250 - $260,000 a year
# 4                                 NaN
# ..                                ...
# 145                               NaN
# 146  $115,568.00 - $151,683.53 a year
# 147              From $134,500 a year
# 148         $94,300 - $182,600 a year
# 149                               NaN
#
#                                            Description  \
# 0    The Center for Computational Research (CCR) at...
# 1    AI Engineer - New York Experience Hire: BAM is...
# 2    Company Description At ServiceNow, our technol...
# 3    Bring your heart to CVS Health. Every one of u...
# 4    About Harry's Harry's Inc. started in 2013 wit...
# ..                                                 ...
# 145  Description Strength Through Diversity Ground ...
# 146  Description POSTING NO. 3979 JOB TITLE: Direct...
# 147  - 5+ years of non-internship professional soft...
# 148  Microsoft Research New York City (MSR NYC) is ...
# 149  Description The Materials Data Associate recor...
#
#                                                  Links
# 0    https://www.indeed.com/rc/clk?jk=33e3b9decf5d0...
# 1    https://www.indeed.com/rc/clk?jk=86a5360917a93...
# 2    https://www.indeed.com/rc/clk?jk=f199691e2f7a7...
# 3    https://www.indeed.com/rc/clk?jk=300ff83543345...
# 4    https://www.indeed.com/rc/clk?jk=d44a402a00875...
# ..                                                 ...
# 145  https://www.indeed.com/rc/clk?jk=f8e5356af5611...
# 146  https://www.indeed.com/rc/clk?jk=e194740b1bf10...
# 147  https://www.indeed.com/rc/clk?jk=92340f0ca3e03...
# 148  https://www.indeed.com/rc/clk?jk=52df5e48bb86d...
# 149  https://www.indeed.com/rc/clk?jk=6c3284685c547...
#
# [150 rows x 8 columns]

# %% [markdown]
# ### Scrape Full Job Descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions

# %% [markdown]
# ### Save Results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + "2.csv", index=False)

# %%
dataframe.head()
# Out:
#                                              Title                Company  \
# 0  Research Computing and Data Science Facilitator  University at Buffalo
# 1   Artificial Intelligence Engineer (AI Engineer)              Integrass
# 2        Senior AI Specialist, Solution Consulting             ServiceNow
# 3            Lead Decision Scientist - EDA Product             CVS Health
# 4                      Senior Data Analyst, Amazon                Harry's
#
#                                        Location Rating  \
# 0            Hybrid remote in Buffalo, NY 14260    NaN
# 1           Hybrid remote in New York, NY 10001    NaN
# 2                        Remote in New York, NY    NaN
# 3                                  New York, NY    NaN
# 4  New York, NY 10004 (Financial District area)    NaN
#
#                                                 Date  \
# 0                          PostedPosted 30+ days ago
# 1                          PostedPosted 30+ days ago
# 2                          PostedPosted 30+ days ago
# 3                           PostedPosted 22 days ago
# 4  PostedPosted 30+ days ago •Many applications i...
#
#                        Salary  \
# 0                         NaN
# 1                         NaN
# 2  $165,825 - $273,675 a year
# 3  $132,250 - $260,000 a year
# 4                         NaN
#
#                                          Description  \
# 0  The Center for Computational Research (CCR) at...
# 1  AI Engineer - New York Experience Hire: BAM is...
# 2  Company Description At ServiceNow, our technol...
# 3  Bring your heart to CVS Health. Every one of u...
# 4  About Harry's Harry's Inc. started in 2013 wit...
#
#                                                Links  \
# 0  https://www.indeed.com/rc/clk?jk=33e3b9decf5d0...
# 1  https://www.indeed.com/rc/clk?jk=86a5360917a93...
# 2  https://www.indeed.com/rc/clk?jk=f199691e2f7a7...
# 3  https://www.indeed.com/rc/clk?jk=300ff83543345...
# 4  https://www.indeed.com/rc/clk?jk=d44a402a00875...
#
#                                         Descriptions
# 0  The Center for Computational Research (CCR) at...
# 1  AI Engineer - New York\nExperience Hire:\nBAM ...
# 2  Company Description\n\nAt ServiceNow, our tech...
# 3  Bring your heart to CVS Health. Every one of u...
# 4  About Harry's\nHarry's Inc. started in 2013 wi...
